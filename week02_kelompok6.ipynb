# %% [markdown]
# <a href="https://colab.research.google.com/github/rzqmhb/PCVK_Ganjil_2023/blob/main/week02_kelompok6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kelompok 6
# Nama Anggota :
#
# - Amalia Salsa Lutfiana (3F/04)
# - Roziq Mahbubi (3F/27)
# - Yofandra Arta Priyoga (3F/30)

# %%
from google.colab import drive

#akses google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/Kuliah_SMT_5/PCVK/KTP.jpeg')
plt.imshow(img)

# %%
ktp = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(ktp, pt1=(190,320), pt2=(490,340), color=(255,0,0), thickness=8)
cv.rectangle(ktp, pt1=(190,350), pt2=(230,370), color=(255,255,0), thickness=7)
plt.imshow(ktp)
