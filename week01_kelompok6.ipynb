# %% [markdown]
# <a href="https://colab.research.google.com/github/rzqmhb/PCVK_Ganjil_2023/blob/main/week01_kelompok6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Kelompok 6
#
# Nama Anggota :
#
# - Amalia Salsa Lutfiana (3F/04)
# - Roziq Mahbubi (3F/27)
# - Yofandra Arta Priyoga (3F/30)

# %%
# @title Langkah 1 :  Import Library
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = io.imread("/content/KTP.jpeg")
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
tinggi = image.shape[0]
lebar = image.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi,"x",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  488 x 800
# <PIL.Image.Image image mode=RGB size=800x488>

# %%
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (320,345):
  for y in range (195,480):
    image_3[x,y] = [200,40,200]

for x in range (350,370):
  for y in range (195,240):
    image_3[x,y] = [200,40,90]

cv2_imshow(image_3)
# Out:
# <PIL.Image.Image image mode=RGB size=800x488>
